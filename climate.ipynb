# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
import json
import csv
import requests
from pprint import pprint as pprint
from IPython.display import display as display

# %%
state_data="data/model_state.csv"

#Read files and store in pandas
state_df = pd.read_csv(state_data)
# state_df.head()
state_df
# Out:
#     fips      fall    spring    summer    winter max_warming_season    annual  \
# 0      1 -0.195668 -0.105862 -0.325009  0.458526             Winter -0.035048
# 1      4  1.203951  1.384480  1.274455  1.388388             Winter  1.319880
# 2      5 -0.042540  0.266399  0.058596  0.532247             Winter  0.214074
# 3      6  1.570921  1.449242  1.478335  1.412430               Fall  1.480561
# 4      8  1.055309  1.436910  1.367845  1.838758             Winter  1.438589
# 5      9  1.453093  1.543407  1.580628  2.633975             Winter  1.801492
# 6     10  1.378949  1.537848  1.522878  2.201002             Winter  1.661683
# 7     12  1.076586  0.860797  0.914455  1.300233             Winter  1.034878
# 8     13  0.251217  0.174462 -0.016056  1.109362             Winter  0.384049
# 9     16  0.686631  1.004868  1.072720  1.409905             Winter  1.046917
# 10    17  0.557305  1.153298  0.217481  1.308741             Winter  0.814420
# ...

# %%
county_data="data/model_county.csv"

#Read files and store in pandas
county_df = pd.read_csv(county_data)
# county_df.head()
county_df
# Out:
#        fips      fall    spring    summer    winter max_warming_season  \
# 0      1001 -0.248564 -0.073735 -0.307132  0.270039             Winter
# 1      1003  0.049693  0.060035 -0.007407  0.444586             Winter
# 2      1005  0.179485  0.127492 -0.061220  0.891132             Winter
# 3      1007 -0.398166 -0.210074 -0.576085  0.530794             Winter
# 4      1009  0.308868  0.333460  0.169764  0.735788             Winter
# ...     ...       ...       ...       ...       ...                ...
# 3102  56037  1.237333  1.709785  1.424254  2.144437             Winter
# 3103  56039  0.265877  1.183083  0.692148  1.308981             Winter
# 3104  56041  1.056832  1.351661  1.272762  1.376028             Winter
# 3105  56043  0.834173  1.287097  0.977354  1.935859             Winter
# 3106  56045  0.901432  1.609256  1.241580  2.186511             Winter
#
#         annual            ctyname   stname
# 0    -0.079968     Autauga County  Alabama
# ...

# %%
state_year_data="data/climdiv_state_year.csv"

#Read files and store in pandas
state_y_df = pd.read_csv(state_year_data)
# state_y_df.head()
state_y_df
# Out:
#       fips  year       temp      tempc
# 0        1  1895  61.641667  16.467593
# 1        1  1896  64.266667  17.925926
# 2        1  1897  64.191667  17.884259
# 3        1  1898  62.983333  17.212963
# 4        1  1899  63.100000  17.277778
# ...    ...   ...        ...        ...
# 5995    56  2015  44.158333   6.754630
# 5996    56  2016  43.908333   6.615741
# 5997    56  2017  43.200000   6.222222
# 5998    56  2018  42.408333   5.782407
# 5999    56  2019  40.383333   4.657407
#
# [6000 rows x 4 columns]

# %%
county_year_data="data/climdiv_county_year.csv"

#Read files and store in pandas
county_y_df = pd.read_csv(county_year_data)
# county_y_df.head()
county_y_df
# Out:
#          fips  year       temp      tempc
# 0        1001  1895  62.633333  17.018519
# 1        1001  1896  65.341667  18.523148
# 2        1001  1897  65.150000  18.416667
# 3        1001  1898  63.816667  17.675926
# 4        1001  1899  63.925000  17.736111
# ...       ...   ...        ...        ...
# 388370  56045  2015  46.633333   8.129630
# 388371  56045  2016  47.250000   8.472222
# 388372  56045  2017  45.650000   7.583333
# 388373  56045  2018  43.725000   6.513889
# 388374  56045  2019  42.300000   5.722222
#
# [388375 rows x 4 columns]
